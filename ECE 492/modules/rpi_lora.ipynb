# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-400458b0622b> in <module>()
#       7
#       8 # Initialize the Rpi Microblaze instance without specifying a firmware file
# ----> 9 rpi = Rpi(mb_info={"ip_name": "iop_rpi/mb_bram_ctrl"})
#      10
#      11 # Step 2: Define a function to send "ACK" over UART
#
# TypeError: __init__() missing 1 required positional argument: 'mb_program'

# %%
# Out:
# ls: cannot access '/usr/local/lib/python3.6/dist-packages/pynq/overlays/pmod': No such file or directory
