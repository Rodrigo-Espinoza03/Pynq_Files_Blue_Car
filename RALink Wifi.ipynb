# %%
from pynq.lib import Wifi
port=Wifi()

# %%
ssid="csun_lab_ckout"
pwd=""
port.connect(ssid,pwd)

# %%
! ping -I wlan0 www.yahoo.com -c 10
# Out:
# PING me-ycpi-cf-www.g06.yahoodns.net (209.73.190.12) from 10.40.229.158 wlan0: 56(84) bytes of data.
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=1 ttl=54 time=2.84 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=2 ttl=54 time=19.5 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=3 ttl=54 time=24.0 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=4 ttl=54 time=5.17 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=5 ttl=54 time=3.20 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=6 ttl=54 time=6.11 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=7 ttl=54 time=7.33 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=8 ttl=54 time=3.28 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=9 ttl=54 time=24.8 ms
# 64 bytes from e2.ycpi.vip.laa.yahoo.com (209.73.190.12): icmp_seq=10 ttl=54 time=3.58 ms
#
# --- me-ycpi-cf-www.g06.yahoodns.net ping statistics ---
# 10 packets transmitted, 10 received, 0% packet loss, time 9013ms
# rtt min/avg/max/mdev = 2.842/9.974/24.780/8.563 ms

# %%
port.reset()
# do not use enter unless wiping out wifi connection
